# %% [markdown]
# <a href="https://colab.research.google.com/github/psrao123/50_days_of_data_analysis/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
